# %%
import subprocess, os
import numpy as np
os.chdir("/media/andres/LFD/andres/newDomain/V083/10Hz/fluid")

# %%
t=np.linspace(2.4, 3, 601)
print(t)
for i in range (601):
    subprocess.run('source /opt/openfoam7/etc/bashrc; pimpleFoam -postProcess -func forceCoeffsIncompressible -time {}'.format(t[i]),
    # Need a shell; need the shell to be Bash
    shell=True, executable='/bin/bash',
    # basic hygiene
    check=True, universal_newlines=True)
# Out:
# [2.4   2.401 2.402 2.403 2.404 2.405 2.406 2.407 2.408 2.409 2.41  2.411
#  2.412 2.413 2.414 2.415 2.416 2.417 2.418 2.419 2.42  2.421 2.422 2.423
#  2.424 2.425 2.426 2.427 2.428 2.429 2.43  2.431 2.432 2.433 2.434 2.435
#  2.436 2.437 2.438 2.439 2.44  2.441 2.442 2.443 2.444 2.445 2.446 2.447
#  2.448 2.449 2.45  2.451 2.452 2.453 2.454 2.455 2.456 2.457 2.458 2.459
#  2.46  2.461 2.462 2.463 2.464 2.465 2.466 2.467 2.468 2.469 2.47  2.471
#  2.472 2.473 2.474 2.475 2.476 2.477 2.478 2.479 2.48  2.481 2.482 2.483
#  2.484 2.485 2.486 2.487 2.488 2.489 2.49  2.491 2.492 2.493 2.494 2.495
#  2.496 2.497 2.498 2.499 2.5   2.501 2.502 2.503 2.504 2.505 2.506 2.507
#  2.508 2.509 2.51  2.511 2.512 2.513 2.514 2.515 2.516 2.517 2.518 2.519
#  2.52  2.521 2.522 2.523 2.524 2.525 2.526 2.527 2.528 2.529 2.53  2.531
#  2.532 2.533 2.534 2.535 2.536 2.537 2.538 2.539 2.54  2.541 2.542 2.543
#  2.544 2.545 2.546 2.547 2.548 2.549 2.55  2.551 2.552 2.553 2.554 2.555
#  2.556 2.557 2.558 2.559 2.56  2.561 2.562 2.563 2.564 2.565 2.566 2.567
#  2.568 2.569 2.57  2.571 2.572 2.573 2.574 2.575 2.576 2.577 2.578 2.579
#  2.58  2.581 2.582 2.583 2.584 2.585 2.586 2.587 2.588 2.589 2.59  2.591
#  2.592 2.593 2.594 2.595 2.596 2.597 2.598 2.599 2.6   2.601 2.602 2.603
#  2.604 2.605 2.606 2.607 2.608 2.609 2.61  2.611 2.612 2.613 2.614 2.615
#  2.616 2.617 2.618 2.619 2.62  2.621 2.622 2.623 2.624 2.625 2.626 2.627
#  2.628 2.629 2.63  2.631 2.632 2.633 2.634 2.635 2.636 2.637 2.638 2.639
#  2.64  2.641 2.642 2.643 2.644 2.645 2.646 2.647 2.648 2.649 2.65  2.651
#  2.652 2.653 2.654 2.655 2.656 2.657 2.658 2.659 2.66  2.661 2.662 2.663
#  2.664 2.665 2.666 2.667 2.668 2.669 2.67  2.671 2.672 2.673 2.674 2.675
#  2.676 2.677 2.678 2.679 2.68  2.681 2.682 2.683 2.684 2.685 2.686 2.687
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  7
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 7-3bcbaf946ae9
# Exec   : pimpleFoam -postProcess -func forceCoeffsIncompressible -time 2.401
# Date   : May 15 2022
# Time   : 12:21:47
# Host   : "andres-linux"
# PID    : 160919
# I/O    : uncollated
# Case   : /media/andres/LFD/andres/newDomain/V083/10Hz/fluid
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 2.401
#
#
# PIMPLE: No convergence criteria found
#
#
# PIMPLE: Corrector convergence criteria found
#         "(U|p)": tolerance 1e-05, relTol 1e-05
#         Calculations will do 100 corrections if the convergence criteria are not met
#
#
# PIMPLE: Operating solver in transient mode with 100 outer correctors
#
#
# Time = 2.401
# Reading field p
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type laminar
# Selecting laminar stress model Stokes
# No MRF models present
#
# No finite volume options present
# forces forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible write:
#     Cm    = -3.92168444846
#     Cd    = -1.48147691974
#     Cl    = -5.74543789943
#     Cl(f) = -6.79440339817
#     Cl(r) = 1.04896549874
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  7
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 7-3bcbaf946ae9
# Exec   : pimpleFoam -postProcess -func forceCoeffsIncompressible -time 2.4019999999999997
# Date   : May 15 2022
# Time   : 12:21:47
# Host   : "andres-linux"
# PID    : 161099
# I/O    : uncollated
# Case   : /media/andres/LFD/andres/newDomain/V083/10Hz/fluid
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 2.402
# PIMPLE: No convergence criteria found
#
#
# PIMPLE: Corrector convergence criteria found
#         "(U|p)": tolerance 1e-05, relTol 1e-05
#         Calculations will do 100 corrections if the convergence criteria are not met
#
#
# PIMPLE: Operating solver in transient mode with 100 outer correctors
#
#
# Time = 2.402
# Reading field p
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type laminar
# Selecting laminar stress model Stokes
# No MRF models present
#
# No finite volume options present
# forces forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible write:
#     Cm    = -4.20381779376
#     Cd    = -1.48884721189
#     Cl    = -6.38498087854
#     Cl(f) = -7.39630823303
#     Cl(r) = 1.01132735449
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  7
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 7-3bcbaf946ae9
# Exec   : pimpleFoam -postProcess -func forceCoeffsIncompressible -time 2.403
# Date   : May 15 2022
# Time   : 12:21:48
# Host   : "andres-linux"
# PID    : 161279
# I/O    : uncollated
# Case   : /media/andres/LFD/andres/newDomain/V083/10Hz/fluid
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 2.403
#
#
# PIMPLE: No convergence criteria found
#
#
# PIMPLE: Corrector convergence criteria found
#         "(U|p)": tolerance 1e-05, relTol 1e-05
#         Calculations will do 100 corrections if the convergence criteria are not met
#
#
# PIMPLE: Operating solver in transient mode with 100 outer correctors
#
#
# Time = 2.403
# Reading field p
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type laminar
# Selecting laminar stress model Stokes
# No MRF models present
#
# No finite volume options present
# forces forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible write:
#     Cm    = -4.48608021738
#     Cd    = -1.47171182273
#     Cl    = -7.04155808307
#     Cl(f) = -8.00685925892
#     Cl(r) = 0.965301175843
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  7
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 7-3bcbaf946ae9
# Exec   : pimpleFoam -postProcess -func forceCoeffsIncompressible -time 2.404
# Date   : May 15 2022
# Time   : 12:21:48
# Host   : "andres-linux"
# PID    : 161459
# I/O    : uncollated
# Case   : /media/andres/LFD/andres/newDomain/V083/10Hz/fluid
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 2.404
#
#
# PIMPLE: No convergence criteria found
#
#
# PIMPLE: Corrector convergence criteria found
#         "(U|p)": tolerance 1e-05, relTol 1e-05
#         Calculations will do 100 corrections if the convergence criteria are not met
#
#
# PIMPLE: Operating solver in transient mode with 100 outer correctors
#
#
# Time = 2.404
# Reading field p
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type laminar
# Selecting laminar stress model Stokes
# No MRF models present
#
# No finite volume options present
# forces forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible write:
#     Cm    = -4.75883023292
#     Cd    = -1.4253763163
#     Cl    = -7.69495015769
#     Cl(f) = -8.60630531176
#     Cl(r) = 0.911355154076
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  7
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 7-3bcbaf946ae9
# Exec   : pimpleFoam -postProcess -func forceCoeffsIncompressible -time 2.405
# Date   : May 15 2022
# Time   : 12:21:49
# Host   : "andres-linux"
# PID    : 161639
# I/O    : uncollated
# Case   : /media/andres/LFD/andres/newDomain/V083/10Hz/fluid
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 2.405
#
#
# PIMPLE: No convergence criteria found
#
#
# PIMPLE: Corrector convergence criteria found
#         "(U|p)": tolerance 1e-05, relTol 1e-05
#         Calculations will do 100 corrections if the convergence criteria are not met
#
#
# PIMPLE: Operating solver in transient mode with 100 outer correctors
#
#
# Time = 2.405
# Reading field p
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type laminar
# Selecting laminar stress model Stokes
# No MRF models present
#
# No finite volume options present
# forces forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible write:
#     Cm    = -5.00737474226
#     Cd    = -1.34527489716
#     Cl    = -8.31831488009
#     Cl(f) = -9.16653218231
#     Cl(r) = 0.848217302217
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  7
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 7-3bcbaf946ae9
# Exec   : pimpleFoam -postProcess -func forceCoeffsIncompressible -time 2.4059999999999997
# Date   : May 15 2022
# Time   : 12:21:49
# Host   : "andres-linux"
# PID    : 161819
# I/O    : uncollated
# Case   : /media/andres/LFD/andres/newDomain/V083/10Hz/fluid
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 2.406
#
#
# PIMPLE: No convergence criteria found
#
#
# PIMPLE: Corrector convergence criteria found
#         "(U|p)": tolerance 1e-05, relTol 1e-05
#         Calculations will do 100 corrections if the convergence criteria are not met
#
#
# PIMPLE: Operating solver in transient mode with 100 outer correctors
#
#
# Time = 2.406
# Reading field p
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type laminar
# Selecting laminar stress model Stokes
# No MRF models present
#
# No finite volume options present
# forces forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible write:
#     Cm    = -5.22703197018
#     Cd    = -1.23211847902
#     Cl    = -8.89501018898
#     Cl(f) = -9.67453706467
#     Cl(r) = 0.779526875692
#
#
# End
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  7
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 7-3bcbaf946ae9
# Exec   : pimpleFoam -postProcess -func forceCoeffsIncompressible -time 2.407
# Date   : May 15 2022
# Time   : 12:21:50
# Host   : "andres-linux"
# PID    : 161999
# I/O    : uncollated
# Case   : /media/andres/LFD/andres/newDomain/V083/10Hz/fluid
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 2.407
#
#
# PIMPLE: No convergence criteria found
#
#
# PIMPLE: Corrector convergence criteria found
#         "(U|p)": tolerance 1e-05, relTol 1e-05
#         Calculations will do 100 corrections if the convergence criteria are not met
#
#
# PIMPLE: Operating solver in transient mode with 100 outer correctors
#
#
# Time = 2.407
# Reading field p
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type laminar
# Selecting laminar stress model Stokes
# No MRF models present
#
# No finite volume options present
# forces forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible write:
#     Cm    = -5.41220745731
#     Cd    = -1.08777613973
#     Cl    = -9.4122620432
#     Cl(f) = -10.1183384789
#     Cl(r) = 0.706076435704
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  7
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 7-3bcbaf946ae9
# Exec   : pimpleFoam -postProcess -func forceCoeffsIncompressible -time 2.408
# Date   : May 15 2022
# Time   : 12:21:50
# Host   : "andres-linux"
# PID    : 162179
# I/O    : uncollated
# Case   : /media/andres/LFD/andres/newDomain/V083/10Hz/fluid
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 2.408
#
#
# PIMPLE: No convergence criteria found
#
#
# PIMPLE: Corrector convergence criteria found
#         "(U|p)": tolerance 1e-05, relTol 1e-05
#         Calculations will do 100 corrections if the convergence criteria are not met
#
#
# PIMPLE: Operating solver in transient mode with 100 outer correctors
#
#
# Time = 2.408
# Reading field p
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type laminar
# Selecting laminar stress model Stokes
# No MRF models present
#
# No finite volume options present
# forces forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible write:
#     Cm    = -5.55592942394
#     Cd    = -0.914805411728
#     Cl    = -9.85291394191
#     Cl(f) = -10.4823863949
#     Cl(r) = 0.62947245299
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  7
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 7-3bcbaf946ae9
# Exec   : pimpleFoam -postProcess -func forceCoeffsIncompressible -time 2.409
# Date   : May 15 2022
# Time   : 12:21:50
# Host   : "andres-linux"
# PID    : 162359
# I/O    : uncollated
# Case   : /media/andres/LFD/andres/newDomain/V083/10Hz/fluid
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 2.409
#
#
# PIMPLE: No convergence criteria found
#
#
# PIMPLE: Corrector convergence criteria found
#         "(U|p)": tolerance 1e-05, relTol 1e-05
#         Calculations will do 100 corrections if the convergence criteria are not met
#
#
# PIMPLE: Operating solver in transient mode with 100 outer correctors
#
#
# Time = 2.409
# Reading field p
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type laminar
# Selecting laminar stress model Stokes
# No MRF models present
#
# No finite volume options present
# forces forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible write:
#     Cm    = -5.66004185247
#     Cd    = -0.719123567809
#     Cl    = -10.2146139601
#     Cl(f) = -10.7673488325
#     Cl(r) = 0.552734872402
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  7
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 7-3bcbaf946ae9
# Exec   : pimpleFoam -postProcess -func forceCoeffsIncompressible -time 2.4099999999999997
# Date   : May 15 2022
# Time   : 12:21:51
# Host   : "andres-linux"
# PID    : 162539
# I/O    : uncollated
# Case   : /media/andres/LFD/andres/newDomain/V083/10Hz/fluid
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 2.41
#
#
# PIMPLE: No convergence criteria found
#
#
# PIMPLE: Corrector convergence criteria found
#         "(U|p)": tolerance 1e-05, relTol 1e-05
#         Calculations will do 100 corrections if the convergence criteria are not met
#
#
# PIMPLE: Operating solver in transient mode with 100 outer correctors
#
#
# Time = 2.41
# Reading field p
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type laminar
# Selecting laminar stress model Stokes
# No MRF models present
#
# No finite volume options present
# forces forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible write:
#     Cm    = -5.72709413005
#     Cd    = -0.50632282745
#     Cl    = -10.5014183541
#     Cl(f) = -10.9778033071
#     Cl(r) = 0.476384953007
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  7
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 7-3bcbaf946ae9
# Exec   : pimpleFoam -postProcess -func forceCoeffsIncompressible -time 2.411
# Date   : May 15 2022
# Time   : 12:21:51
# Host   : "andres-linux"
# PID    : 162719
# I/O    : uncollated
# Case   : /media/andres/LFD/andres/newDomain/V083/10Hz/fluid
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 2.411
#
#
# PIMPLE: No convergence criteria found
#
#
# PIMPLE: Corrector convergence criteria found
#         "(U|p)": tolerance 1e-05, relTol 1e-05
#         Calculations will do 100 corrections if the convergence criteria are not met
#
#
# PIMPLE: Operating solver in transient mode with 100 outer correctors
#
#
# Time = 2.411
# Reading field p
# Reading field U
#
# Reading/calculating face flux field phi
#
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type laminar
# Selecting laminar stress model Stokes
# No MRF models present
#
# No finite volume options present
# forces forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible write:
#     Cm    = -5.76071965209
#     Cd    = -0.282167073116
#     Cl    = -10.7175614312
#     Cl(f) = -11.1195003677
#     Cl(r) = 0.401938936502
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  7
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 7-3bcbaf946ae9
# Exec   : pimpleFoam -postProcess -func forceCoeffsIncompressible -time 2.412
# Date   : May 15 2022
# Time   : 12:21:52
# Host   : "andres-linux"
# PID    : 162899
# I/O    : uncollated
# Case   : /media/andres/LFD/andres/newDomain/V083/10Hz/fluid
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 2.412
#
#
# PIMPLE: No convergence criteria found
#
#
# PIMPLE: Corrector convergence criteria found
#         "(U|p)": tolerance 1e-05, relTol 1e-05
#         Calculations will do 100 corrections if the convergence criteria are not met
#
#
# PIMPLE: Operating solver in transient mode with 100 outer correctors
#
#
# Time = 2.412
# Reading field p
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type laminar
# Selecting laminar stress model Stokes
# No MRF models present
#
# No finite volume options present
# forces forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible write:
#     Cm    = -5.76599648381
#     Cd    = -0.0516883369183
#     Cl    = -10.8732601404
#     Cl(f) = -11.202626554
#     Cl(r) = 0.32936641361
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  7
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 7-3bcbaf946ae9
# Exec   : pimpleFoam -postProcess -func forceCoeffsIncompressible -time 2.413
# Date   : May 15 2022
# Time   : 12:21:52
# Host   : "andres-linux"
# PID    : 163079
# I/O    : uncollated
# Case   : /media/andres/LFD/andres/newDomain/V083/10Hz/fluid
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 2.413
#
#
# PIMPLE: No convergence criteria found
#
#
# PIMPLE: Corrector convergence criteria found
#         "(U|p)": tolerance 1e-05, relTol 1e-05
#         Calculations will do 100 corrections if the convergence criteria are not met
#
#
# PIMPLE: Operating solver in transient mode with 100 outer correctors
#
#
# Time = 2.413
# Reading field p
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type laminar
# Selecting laminar stress model Stokes
# No MRF models present
#
# No finite volume options present
# forces forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible write:
#     Cm    = -5.74879961488
#     Cd    = 0.181063718735
#     Cl    = -10.9849090795
#     Cl(f) = -11.2412541546
#     Cl(r) = 0.256345075144
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  7
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 7-3bcbaf946ae9
# Exec   : pimpleFoam -postProcess -func forceCoeffsIncompressible -time 2.4139999999999997
# Date   : May 15 2022
# Time   : 12:21:53
# Host   : "andres-linux"
# PID    : 163259
# I/O    : uncollated
# Case   : /media/andres/LFD/andres/newDomain/V083/10Hz/fluid
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 2.414
#
#
# PIMPLE: No convergence criteria found
#
#
# PIMPLE: Corrector convergence criteria found
#         "(U|p)": tolerance 1e-05, relTol 1e-05
#         Calculations will do 100 corrections if the convergence criteria are not met
#
#
# PIMPLE: Operating solver in transient mode with 100 outer correctors
#
#
# Time = 2.414
# Reading field p
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type laminar
# Selecting laminar stress model Stokes
# No MRF models present
#
# No finite volume options present
# forces forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible write:
#     Cm    = -5.70839107074
#     Cd    = 0.412651122327
#     Cl    = -11.0504621393
#     Cl(f) = -11.2336221404
#     Cl(r) = 0.183160001064
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  7
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 7-3bcbaf946ae9
# Exec   : pimpleFoam -postProcess -func forceCoeffsIncompressible -time 2.415
# Date   : May 15 2022
# Time   : 12:21:53
# Host   : "andres-linux"
# PID    : 163439
# I/O    : uncollated
# Case   : /media/andres/LFD/andres/newDomain/V083/10Hz/fluid
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 2.415
#
#
# PIMPLE: No convergence criteria found
#
#
# PIMPLE: Corrector convergence criteria found
#         "(U|p)": tolerance 1e-05, relTol 1e-05
#         Calculations will do 100 corrections if the convergence criteria are not met
#
#
# PIMPLE: Operating solver in transient mode with 100 outer correctors
#
#
# Time = 2.415
# Reading field p
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type laminar
# Selecting laminar stress model Stokes
# No MRF models present
#
# No finite volume options present
# forces forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible write:
#     Cm    = -5.65127495832
#     Cd    = 0.640412525744
#     Cl    = -11.0880907042
#     Cl(f) = -11.1953203104
#     Cl(r) = 0.107229606227
#
#
# End
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  7
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 7-3bcbaf946ae9
# Exec   : pimpleFoam -postProcess -func forceCoeffsIncompressible -time 2.416
# Date   : May 15 2022
# Time   : 12:21:54
# Host   : "andres-linux"
# PID    : 163619
# I/O    : uncollated
# Case   : /media/andres/LFD/andres/newDomain/V083/10Hz/fluid
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 2.416
#
#
# PIMPLE: No convergence criteria found
#
#
# PIMPLE: Corrector convergence criteria found
#         "(U|p)": tolerance 1e-05, relTol 1e-05
#         Calculations will do 100 corrections if the convergence criteria are not met
#
#
# PIMPLE: Operating solver in transient mode with 100 outer correctors
#
#
# Time = 2.416
# Reading field p
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type laminar
# Selecting laminar stress model Stokes
# No MRF models present
#
# No finite volume options present
# forces forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible write:
#     Cm    = -5.56806835335
#     Cd    = 0.86066256513
#     Cl    = -11.0800317821
#     Cl(f) = -11.1080842444
#     Cl(r) = 0.0280524623063
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  7
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 7-3bcbaf946ae9
# Exec   : pimpleFoam -postProcess -func forceCoeffsIncompressible -time 2.417
# Date   : May 15 2022
# Time   : 12:21:54
# Host   : "andres-linux"
# PID    : 163799
# I/O    : uncollated
# Case   : /media/andres/LFD/andres/newDomain/V083/10Hz/fluid
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 2.417
#
#
# PIMPLE: No convergence criteria found
#
#
# PIMPLE: Corrector convergence criteria found
#         "(U|p)": tolerance 1e-05, relTol 1e-05
#         Calculations will do 100 corrections if the convergence criteria are not met
#
#
# PIMPLE: Operating solver in transient mode with 100 outer correctors
#
#
# Time = 2.417
# Reading field p
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type laminar
# Selecting laminar stress model Stokes
# No MRF models present
#
# No finite volume options present
# forces forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible write:
#     Cm    = -5.45989659226
#     Cd    = 1.06989237207
#     Cl    = -11.0305864613
#     Cl(f) = -10.9751898229
#     Cl(r) = -0.0553966383657
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  7
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 7-3bcbaf946ae9
# Exec   : pimpleFoam -postProcess -func forceCoeffsIncompressible -time 2.4179999999999997
# Date   : May 15 2022
# Time   : 12:21:55
# Host   : "andres-linux"
# PID    : 163980
# I/O    : uncollated
# Case   : /media/andres/LFD/andres/newDomain/V083/10Hz/fluid
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 2.418
#
#
# PIMPLE: No convergence criteria found
#
#
# PIMPLE: Corrector convergence criteria found
#         "(U|p)": tolerance 1e-05, relTol 1e-05
#         Calculations will do 100 corrections if the convergence criteria are not met
#
#
# PIMPLE: Operating solver in transient mode with 100 outer correctors
#
#
# Time = 2.418
# Reading field p
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type laminar
# Selecting laminar stress model Stokes
# No MRF models present
#
# No finite volume options present
# forces forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible write:
#     Cm    = -5.32218612235
#     Cd    = 1.26344298698
#     Cl    = -10.9300304802
#     Cl(f) = -10.7872013625
#     Cl(r) = -0.142829117758
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  7
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 7-3bcbaf946ae9
# Exec   : pimpleFoam -postProcess -func forceCoeffsIncompressible -time 2.419
# Date   : May 15 2022
# Time   : 12:21:55
# Host   : "andres-linux"
# PID    : 164160
# I/O    : uncollated
# Case   : /media/andres/LFD/andres/newDomain/V083/10Hz/fluid
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 2.419
#
#
# PIMPLE: No convergence criteria found
#
#
# PIMPLE: Corrector convergence criteria found
#         "(U|p)": tolerance 1e-05, relTol 1e-05
#         Calculations will do 100 corrections if the convergence criteria are not met
#
#
# PIMPLE: Operating solver in transient mode with 100 outer correctors
#
#
# Time = 2.419
# Reading field p
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type laminar
# Selecting laminar stress model Stokes
# No MRF models present
#
# No finite volume options present
# forces forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible write:
#     Cm    = -5.15226959815
#     Cd    = 1.43641522289
#     Cl    = -10.7708546576
#     Cl(f) = -10.5376969269
#     Cl(r) = -0.233157730649
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  7
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 7-3bcbaf946ae9
# Exec   : pimpleFoam -postProcess -func forceCoeffsIncompressible -time 2.42
# Date   : May 15 2022
# Time   : 12:21:56
# Host   : "andres-linux"
# PID    : 164340
# I/O    : uncollated
# Case   : /media/andres/LFD/andres/newDomain/V083/10Hz/fluid
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 2.42
# PIMPLE: No convergence criteria found
#
#
# PIMPLE: Corrector convergence criteria found
#         "(U|p)": tolerance 1e-05, relTol 1e-05
#         Calculations will do 100 corrections if the convergence criteria are not met
#
#
# PIMPLE: Operating solver in transient mode with 100 outer correctors
#
#
# Time = 2.42
# Reading field p
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type laminar
# Selecting laminar stress model Stokes
# No MRF models present
#
# No finite volume options present
# forces forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible write:
#     Cm    = -4.94748410928
#     Cd    = 1.58356836118
#     Cl    = -10.5440726052
#     Cl(f) = -10.2195204119
#     Cl(r) = -0.324552193309
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  7
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 7-3bcbaf946ae9
# Exec   : pimpleFoam -postProcess -func forceCoeffsIncompressible -time 2.421
# Date   : May 15 2022
# Time   : 12:21:56
# Host   : "andres-linux"
# PID    : 164520
# I/O    : uncollated
# Case   : /media/andres/LFD/andres/newDomain/V083/10Hz/fluid
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 2.421
#
#
# PIMPLE: No convergence criteria found
#
#
# PIMPLE: Corrector convergence criteria found
#         "(U|p)": tolerance 1e-05, relTol 1e-05
#         Calculations will do 100 corrections if the convergence criteria are not met
#
#
# PIMPLE: Operating solver in transient mode with 100 outer correctors
#
#
# Time = 2.421
# Reading field p
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type laminar
# Selecting laminar stress model Stokes
# No MRF models present
#
# No finite volume options present
# forces forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible write:
#     Cm    = -4.70982582879
#     Cd    = 1.70077145855
#     Cl    = -10.2487849505
#     Cl(f) = -9.83421830405
#     Cl(r) = -0.414566646462
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  7
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 7-3bcbaf946ae9
# Exec   : pimpleFoam -postProcess -func forceCoeffsIncompressible -time 2.4219999999999997
# Date   : May 15 2022
# Time   : 12:21:56
# Host   : "andres-linux"
# PID    : 164700
# I/O    : uncollated
# Case   : /media/andres/LFD/andres/newDomain/V083/10Hz/fluid
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 2.422
#
#
# PIMPLE: No convergence criteria found
#
#
# PIMPLE: Corrector convergence criteria found
#         "(U|p)": tolerance 1e-05, relTol 1e-05
#         Calculations will do 100 corrections if the convergence criteria are not met
#
#
# PIMPLE: Operating solver in transient mode with 100 outer correctors
#
#
# Time = 2.422
# Reading field p
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type laminar
# Selecting laminar stress model Stokes
# No MRF models present
#
# No finite volume options present
# forces forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible write:
#     Cm    = -4.43992228098
#     Cd    = 1.78481323722
#     Cl    = -9.8841494375
# ...
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type laminar
# Selecting laminar stress model Stokes
# No MRF models present
#
# No finite volume options present
# forces forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible write:
#     Cm    = -5.74836620037
#     Cd    = 0.181099391179
#     Cl    = -10.9846815866
#     Cl(f) = -11.2407069937
#     Cl(r) = 0.256025407079
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  7
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 7-3bcbaf946ae9
# Exec   : pimpleFoam -postProcess -func forceCoeffsIncompressible -time 2.914
# Date   : May 15 2022
# Time   : 12:26:58
# Host   : "andres-linux"
# PID    : 253922
# I/O    : uncollated
# Case   : /media/andres/LFD/andres/newDomain/V083/10Hz/fluid
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 2.914
#
#
# PIMPLE: No convergence criteria found
#
#
# PIMPLE: Corrector convergence criteria found
#         "(U|p)": tolerance 1e-05, relTol 1e-05
#         Calculations will do 100 corrections if the convergence criteria are not met
#
#
# PIMPLE: Operating solver in transient mode with 100 outer correctors
#
#
# Time = 2.914
# Reading field p
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type laminar
# Selecting laminar stress model Stokes
# No MRF models present
#
# No finite volume options present
# forces forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible write:
#     Cm    = -5.70996891955
#     Cd    = 0.412747231608
#     Cl    = -11.0541479553
#     Cl(f) = -11.2370428972
#     Cl(r) = 0.182894941917
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  7
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 7-3bcbaf946ae9
# Exec   : pimpleFoam -postProcess -func forceCoeffsIncompressible -time 2.915
# Date   : May 15 2022
# Time   : 12:26:59
# Host   : "andres-linux"
# PID    : 254102
# I/O    : uncollated
# Case   : /media/andres/LFD/andres/newDomain/V083/10Hz/fluid
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 2.915
# PIMPLE: No convergence criteria found
#
#
# PIMPLE: Corrector convergence criteria found
#         "(U|p)": tolerance 1e-05, relTol 1e-05
#         Calculations will do 100 corrections if the convergence criteria are not met
#
#
# PIMPLE: Operating solver in transient mode with 100 outer correctors
#
#
# Time = 2.915
# Reading field p
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type laminar
# Selecting laminar stress model Stokes
# No MRF models present
#
# No finite volume options present
# forces forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible write:
#     Cm    = -5.65109947692
#     Cd    = 0.640361713396
#     Cl    = -11.0875181312
#     Cl(f) = -11.1948585425
#     Cl(r) = 0.107340411335
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  7
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 7-3bcbaf946ae9
# Exec   : pimpleFoam -postProcess -func forceCoeffsIncompressible -time 2.916
# Date   : May 15 2022
# Time   : 12:26:59
# Host   : "andres-linux"
# PID    : 254294
# I/O    : uncollated
# Case   : /media/andres/LFD/andres/newDomain/V083/10Hz/fluid
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 2.916
#
#
# PIMPLE: No convergence criteria found
#
#
# PIMPLE: Corrector convergence criteria found
#         "(U|p)": tolerance 1e-05, relTol 1e-05
#         Calculations will do 100 corrections if the convergence criteria are not met
#
#
# PIMPLE: Operating solver in transient mode with 100 outer correctors
#
#
# Time = 2.916
# Reading field p
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type laminar
# Selecting laminar stress model Stokes
# No MRF models present
#
# No finite volume options present
# forces forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible write:
#     Cm    = -5.56813564216
#     Cd    = 0.860582938968
#     Cl    = -11.0794538734
#     Cl(f) = -11.1078625788
#     Cl(r) = 0.0284087054845
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  7
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 7-3bcbaf946ae9
# Exec   : pimpleFoam -postProcess -func forceCoeffsIncompressible -time 2.917
# Date   : May 15 2022
# Time   : 12:27:00
# Host   : "andres-linux"
# PID    : 254474
# I/O    : uncollated
# Case   : /media/andres/LFD/andres/newDomain/V083/10Hz/fluid
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 2.917
#
#
# PIMPLE: No convergence criteria found
#
#
# PIMPLE: Corrector convergence criteria found
#         "(U|p)": tolerance 1e-05, relTol 1e-05
#         Calculations will do 100 corrections if the convergence criteria are not met
#
#
# PIMPLE: Operating solver in transient mode with 100 outer correctors
#
#
# Time = 2.917
# Reading field p
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type laminar
# Selecting laminar stress model Stokes
# No MRF models present
#
# No finite volume options present
# forces forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible write:
#     Cm    = -5.4595666446
#     Cd    = 1.06983546348
#     Cl    = -11.0300149641
#     Cl(f) = -10.9745741266
#     Cl(r) = -0.0554408374361
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  7
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 7-3bcbaf946ae9
# Exec   : pimpleFoam -postProcess -func forceCoeffsIncompressible -time 2.918
# Date   : May 15 2022
# Time   : 12:27:01
# Host   : "andres-linux"
# PID    : 254654
# I/O    : uncollated
# Case   : /media/andres/LFD/andres/newDomain/V083/10Hz/fluid
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 2.918
#
#
# PIMPLE: No convergence criteria found
#
#
# PIMPLE: Corrector convergence criteria found
#         "(U|p)": tolerance 1e-05, relTol 1e-05
#         Calculations will do 100 corrections if the convergence criteria are not met
#
#
# PIMPLE: Operating solver in transient mode with 100 outer correctors
#
#
# Time = 2.918
# Reading field p
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type laminar
# Selecting laminar stress model Stokes
# No MRF models present
#
# No finite volume options present
# forces forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible write:
#     Cm    = -5.32255704999
#     Cd    = 1.26353714649
#     Cl    = -10.9311078346
#     Cl(f) = -10.7881109673
#     Cl(r) = -0.142996867286
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  7
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 7-3bcbaf946ae9
# Exec   : pimpleFoam -postProcess -func forceCoeffsIncompressible -time 2.919
# Date   : May 15 2022
# Time   : 12:27:01
# Host   : "andres-linux"
# PID    : 254834
# I/O    : uncollated
# Case   : /media/andres/LFD/andres/newDomain/V083/10Hz/fluid
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 2.919
#
#
# PIMPLE: No convergence criteria found
#
#
# PIMPLE: Corrector convergence criteria found
#         "(U|p)": tolerance 1e-05, relTol 1e-05
#         Calculations will do 100 corrections if the convergence criteria are not met
#
#
# PIMPLE: Operating solver in transient mode with 100 outer correctors
#
#
# Time = 2.919
# Reading field p
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type laminar
# Selecting laminar stress model Stokes
# No MRF models present
#
# No finite volume options present
# forces forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible write:
#     Cm    = -5.15200199056
#     Cd    = 1.43641150581
#     Cl    = -10.7708954969
#     Cl(f) = -10.537449739
#     Cl(r) = -0.233445757868
#
#
# End
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  7
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 7-3bcbaf946ae9
# Exec   : pimpleFoam -postProcess -func forceCoeffsIncompressible -time 2.92
# Date   : May 15 2022
# Time   : 12:27:02
# Host   : "andres-linux"
# PID    : 255014
# I/O    : uncollated
# Case   : /media/andres/LFD/andres/newDomain/V083/10Hz/fluid
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 2.92
#
#
# PIMPLE: No convergence criteria found
#
#
# PIMPLE: Corrector convergence criteria found
#         "(U|p)": tolerance 1e-05, relTol 1e-05
#         Calculations will do 100 corrections if the convergence criteria are not met
#
#
# PIMPLE: Operating solver in transient mode with 100 outer correctors
#
#
# Time = 2.92
# Reading field p
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type laminar
# Selecting laminar stress model Stokes
# No MRF models present
#
# No finite volume options present
# forces forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible write:
#     Cm    = -4.9475594419
#     Cd    = 1.583558712
#     Cl    = -10.5440436416
#     Cl(f) = -10.2195812627
#     Cl(r) = -0.324462378896
#
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  7
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 7-3bcbaf946ae9
# Exec   : pimpleFoam -postProcess -func forceCoeffsIncompressible -time 2.9210000000000003
# Date   : May 15 2022
# Time   : 12:27:03
# Host   : "andres-linux"
# PID    : 255194
# I/O    : uncollated
# Case   : /media/andres/LFD/andres/newDomain/V083/10Hz/fluid
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 2.921
#
#
# PIMPLE: No convergence criteria found
#
#
# PIMPLE: Corrector convergence criteria found
#         "(U|p)": tolerance 1e-05, relTol 1e-05
#         Calculations will do 100 corrections if the convergence criteria are not met
#
#
# PIMPLE: Operating solver in transient mode with 100 outer correctors
#
#
# Time = 2.921
# Reading field p
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type laminar
# Selecting laminar stress model Stokes
# No MRF models present
#
# No finite volume options present
# forces forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible:
#     Not including porosity effects
# forceCoeffs forceCoeffsIncompressible write:
#     Cm    = -4.7097647711
#     Cd    = 1.70071405012
#     Cl    = -10.2483217383
#     Cl(f) = -9.83392564024
#     Cl(r) = -0.414396098037
#
#
# End
